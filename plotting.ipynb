# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point,Polygon
# %matplotlib inline
street_map=gpd.read_file(r'C:\Users\Adarsh\Downloads\TM_WORLD_BORDERS_SIMPL-0.3\TM_WORLD_BORDERS_SIMPL-0.3.shp')
fig,ax=plt.subplots(figsize=(15,15))
street_map.plot(ax=ax)

# %%
df1=pd.read_csv(r'C:\Users\Adarsh\opc.csv')
crs={'init':'epsg:4326'}
#crs.encode('utf-8').strip()
df1.head()



df1.shape
# Out:
# (6120, 8)

# %%
geometry=[Point(xy) for xy in zip(df1["Longititude"],df1["Latitude"])]
geometry[:3]
df=gpd.GeoDataFrame(df1,crs=crs,geometry=geometry)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1              Date  \
# 0           0             0  02-03-2020 23:12
# 1           1             1  02-03-2020 23:12
# 2           2             3  02-03-2020 23:12
# 3           3             4  02-03-2020 23:12
# 4           4             6  02-03-2020 23:12
#
#                                               Tweets          Location  \
# 0  Coronavirus Testing What To Know As It Becomes...  Edmonton Alberta
# 1  atrupar Listening to realDonaldTrump makes him...       los angeles
# 2  BernieSanders is worse than the CoronaVirus If...    Scottsdale, AZ
# 3  CDCgov IS ENGAGED IN A COVERUP WHICH WILL KILL...     United States
# 4  am I the only one frustrated by the ableist an...  East Lansing, MI
#
#     Latitude  Longititude                    Address  \
# 0  53.535411  -113.507996                     Canada
# 1  34.053691  -118.242767   United States of America
# 2  33.494219  -111.926018   United States of America
# ...

# %%
fig,ax=plt.subplots(figsize=(15,15))
street_map.plot(ax=ax,alpha=0.4,color='grey')
df[df['Address']==" United States"].plot(ax=ax,markersize=20,color='blue',marker="o",label="US")
df[df['Address']==" United States of America"].plot(ax=ax,markersize=20,color='blue',marker="o",label="US")
df[df['Address']==" Nederland"].plot(ax=ax,markersize=20,color='red',marker="^",label="NE")
df[df['Address']=="Canada"].plot(ax=ax,markersize=20,color='green',marker="o",label="CA")
df[df['Address']=="United Kingdom"].plot(ax=ax,markersize=20,color='yellow',marker="*",label="UK")
df[df['Address']=="Ireland"].plot(ax=ax,markersize=20,color='orange',marker="o",label="IL")
df[df['Address']=="India"].plot(ax=ax,markersize=20,color='black',marker="o",label="IN")
df[df['Address']=="Australia"].plot(ax=ax,markersize=20,color='violet',marker="o",label="AUS")
df[df['Address']=="Africa"].plot(ax=ax,markersize=20,color='brown',marker="o",label="Africa")
df[df['Address']=="South Africa"].plot(ax=ax,markersize=20,color='gold',marker="o",label="SA")
df[df['Address']==" France"].plot(ax=ax,markersize=20,color='black',marker="o",label="FRA")
df[df['Address']=="Sri Lanka"].plot(ax=ax,markersize=20,color='black',marker="o",label="SL")
df[df['Address']=="New Zealand"].plot(ax=ax,markersize=20,color='black',marker="o",label="NL")
df[df['Address']=="Deutschland"].plot(ax=ax,markersize=20,color='indigo',marker="o",label="GE")
df[df['Address']=="China"].plot(ax=ax,markersize=20,color='indigo',marker="o",label="China")
df[df['Address']==" Brasil"].plot(ax=ax,markersize=20,color='indigo',marker="o",label="Brazil")

plt.legend(prop={'size':10})
# Out:
# C:\Users\Adarsh\Anaconda3\lib\site-packages\geopandas\plotting.py:487: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# C:\Users\Adarsh\Anaconda3\lib\site-packages\geopandas\plotting.py:487: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# C:\Users\Adarsh\Anaconda3\lib\site-packages\geopandas\plotting.py:487: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %%
#sd=[]
sd=df['Address'].unique()
fig,ax=plt.subplots(figsize=(15,15))
street_map.plot(ax=ax,alpha=0.4,color='grey')

for i in sd:
    #print(i)
    df[df['Address']==str(i)].plot(ax=ax,markersize=20,color='blue',marker="o",label=str(i))

# %%
import random
colormark=['blue','red','green','orange','black','gold','silver','indigo','grey','pink','violet','yellow','brown','purple','rose']
random.shuffle(colormark)
x=str(colormark.pop())
print(x)
# Out:
# green

# %%
import random
import numpy as np
colormark=['blue','red','green','orange','black','gold','silver','indigo','grey','pink','violet','yellow','brown']
random.shuffle(colormark)
z = np.array([0,0,1,1,0,1])
#colormark.
sd=df['Address'].unique()
fig,ax=plt.subplots(figsize=(15,15))
street_map.plot(ax=ax,alpha=0.4,color='grey')
j=0;
#colors = rng.rand(12)
for i in sd:
    #print(j)
    #x=str(colormark.pop())
    #print(x)
    df[df['Address']==str(i)].plot(ax=ax,markersize=20,color=colormark[j],marker="o",label=str(i))
    j+=1
    if(j>12):
     j=0
plt.legend(prop={'size':10})
# Out:
# C:\Users\Adarsh\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 3521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Adarsh\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 3530 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Adarsh\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 3515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Adarsh\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 3539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Adarsh\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 3517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
